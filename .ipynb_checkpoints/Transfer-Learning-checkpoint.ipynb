# %% [markdown]
# # Dataset

# %%
import os
import torch
from torch import nn
import torchvision
from torchvision import transforms
from torchvision import datasets
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader

# %%
base_dir = r"/Users/h383kim/pytorch/AlexNet/splitted"
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

BATCH_SIZE = 128

img_transform = transforms.Compose([
    transforms.Resize(size=(224, 224)),
    transforms.ToTensor()
])

train_dataset = ImageFolder(root=train_dir,
                            transform=img_transform)
val_dataset = ImageFolder(root=val_dir,
                          transform=img_transform)
test_dataset = ImageFolder(root=test_dir, 
                           transform=img_transform)

train_dataloader = DataLoader(dataset=train_dataset,
                              batch_size=BATCH_SIZE,
                              shuffle=True,
                              num_workers=os.cpu_count())
val_dataloader = DataLoader(dataset=val_dataset,
                            batch_size=BATCH_SIZE,
                            shuffle=True,
                            num_workers=os.cpu_count())
test_dataloader = DataLoader(dataset=test_dataset,
                            batch_size=BATCH_SIZE,
                            shuffle=False,
                            num_workers=os.cpu_count())

# %% [markdown]
# # Pre-trained and Fine-tuning

# %%
from torchvision import models

ResNet152 = models.resnet152(weights="IMAGENET1K_V2", progress=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet152-f82ba261.pth" to /Users/h383kim/.cache/torch/hub/checkpoints/resnet152-f82ba261.pth
# 100%|████████████████████████████████████████| 230M/230M [00:05<00:00, 46.0MB/s]

# %%
from torchsummary import summary

#summary(ResNet152, input_size=(3, 224, 224), device="cpu") 
print(ResNet152)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
NUM_CLASSES = 10
IN_FEATURES = ResNet152.fc.in_features
# Modifying the model
ResNet152.fc = nn.Linear(in_features=IN_FEATURES, out_features=NUM_CLASSES)
print(ResNet152.fc)
# Out:
# Linear(in_features=2048, out_features=10, bias=True)

# %%
for name, child in ResNet152.named_children():
    if name != "fc":
        for param in child.parameters():
            param.requires_grad = False

# %%
print("After Freezing...")
for name, param in ResNet152.named_parameters():
    print(f"Layer: {name} | requires_grad: {param.requires_grad}")
# Out:
# After Freezing...
# Layer: conv1.weight | requires_grad: False
# Layer: bn1.weight | requires_grad: False
# Layer: bn1.bias | requires_grad: False
# Layer: layer1.0.conv1.weight | requires_grad: False
# Layer: layer1.0.bn1.weight | requires_grad: False
# Layer: layer1.0.bn1.bias | requires_grad: False
# Layer: layer1.0.conv2.weight | requires_grad: False
# Layer: layer1.0.bn2.weight | requires_grad: False
# Layer: layer1.0.bn2.bias | requires_grad: False
# Layer: layer1.0.conv3.weight | requires_grad: False
# Layer: layer1.0.bn3.weight | requires_grad: False
# Layer: layer1.0.bn3.bias | requires_grad: False
# Layer: layer1.0.downsample.0.weight | requires_grad: False
# Layer: layer1.0.downsample.1.weight | requires_grad: False
# Layer: layer1.0.downsample.1.bias | requires_grad: False
# Layer: layer1.1.conv1.weight | requires_grad: False
# Layer: layer1.1.bn1.weight | requires_grad: False
# Layer: layer1.1.bn1.bias | requires_grad: False
# Layer: layer1.1.conv2.weight | requires_grad: False
# Layer: layer1.1.bn2.weight | requires_grad: False
# Layer: layer1.1.bn2.bias | requires_grad: False
# Layer: layer1.1.conv3.weight | requires_grad: False
# Layer: layer1.1.bn3.weight | requires_grad: False
# Layer: layer1.1.bn3.bias | requires_grad: False
# Layer: layer1.2.conv1.weight | requires_grad: False
# Layer: layer1.2.bn1.weight | requires_grad: False
# Layer: layer1.2.bn1.bias | requires_grad: False
# Layer: layer1.2.conv2.weight | requires_grad: False
# Layer: layer1.2.bn2.weight | requires_grad: False
# Layer: layer1.2.bn2.bias | requires_grad: False
# Layer: layer1.2.conv3.weight | requires_grad: False
# Layer: layer1.2.bn3.weight | requires_grad: False
# Layer: layer1.2.bn3.bias | requires_grad: False
# Layer: layer2.0.conv1.weight | requires_grad: False
# Layer: layer2.0.bn1.weight | requires_grad: False
# Layer: layer2.0.bn1.bias | requires_grad: False
# Layer: layer2.0.conv2.weight | requires_grad: False
# Layer: layer2.0.bn2.weight | requires_grad: False
# Layer: layer2.0.bn2.bias | requires_grad: False
# Layer: layer2.0.conv3.weight | requires_grad: False
# Layer: layer2.0.bn3.weight | requires_grad: False
# Layer: layer2.0.bn3.bias | requires_grad: False
# Layer: layer2.0.downsample.0.weight | requires_grad: False
# Layer: layer2.0.downsample.1.weight | requires_grad: False
# Layer: layer2.0.downsample.1.bias | requires_grad: False
# Layer: layer2.1.conv1.weight | requires_grad: False
# Layer: layer2.1.bn1.weight | requires_grad: False
# Layer: layer2.1.bn1.bias | requires_grad: False
# Layer: layer2.1.conv2.weight | requires_grad: False
# Layer: layer2.1.bn2.weight | requires_grad: False
# Layer: layer2.1.bn2.bias | requires_grad: False
# Layer: layer2.1.conv3.weight | requires_grad: False
# Layer: layer2.1.bn3.weight | requires_grad: False
# Layer: layer2.1.bn3.bias | requires_grad: False
# Layer: layer2.2.conv1.weight | requires_grad: False
# Layer: layer2.2.bn1.weight | requires_grad: False
# Layer: layer2.2.bn1.bias | requires_grad: False
# Layer: layer2.2.conv2.weight | requires_grad: False
# Layer: layer2.2.bn2.weight | requires_grad: False
# Layer: layer2.2.bn2.bias | requires_grad: False
# Layer: layer2.2.conv3.weight | requires_grad: False
# Layer: layer2.2.bn3.weight | requires_grad: False
# Layer: layer2.2.bn3.bias | requires_grad: False
# Layer: layer2.3.conv1.weight | requires_grad: False
# Layer: layer2.3.bn1.weight | requires_grad: False
# Layer: layer2.3.bn1.bias | requires_grad: False
# Layer: layer2.3.conv2.weight | requires_grad: False
# Layer: layer2.3.bn2.weight | requires_grad: False
# Layer: layer2.3.bn2.bias | requires_grad: False
# Layer: layer2.3.conv3.weight | requires_grad: False
# Layer: layer2.3.bn3.weight | requires_grad: False
# Layer: layer2.3.bn3.bias | requires_grad: False
# Layer: layer2.4.conv1.weight | requires_grad: False
# Layer: layer2.4.bn1.weight | requires_grad: False
# Layer: layer2.4.bn1.bias | requires_grad: False
# Layer: layer2.4.conv2.weight | requires_grad: False
# Layer: layer2.4.bn2.weight | requires_grad: False
# Layer: layer2.4.bn2.bias | requires_grad: False
# Layer: layer2.4.conv3.weight | requires_grad: False
# Layer: layer2.4.bn3.weight | requires_grad: False
# Layer: layer2.4.bn3.bias | requires_grad: False
# Layer: layer2.5.conv1.weight | requires_grad: False
# Layer: layer2.5.bn1.weight | requires_grad: False
# Layer: layer2.5.bn1.bias | requires_grad: False
# Layer: layer2.5.conv2.weight | requires_grad: False
# Layer: layer2.5.bn2.weight | requires_grad: False
# Layer: layer2.5.bn2.bias | requires_grad: False
# Layer: layer2.5.conv3.weight | requires_grad: False
# Layer: layer2.5.bn3.weight | requires_grad: False
# Layer: layer2.5.bn3.bias | requires_grad: False
# Layer: layer2.6.conv1.weight | requires_grad: False
# Layer: layer2.6.bn1.weight | requires_grad: False
# Layer: layer2.6.bn1.bias | requires_grad: False
# Layer: layer2.6.conv2.weight | requires_grad: False
# Layer: layer2.6.bn2.weight | requires_grad: False
# Layer: layer2.6.bn2.bias | requires_grad: False
# Layer: layer2.6.conv3.weight | requires_grad: False
# Layer: layer2.6.bn3.weight | requires_grad: False
# Layer: layer2.6.bn3.bias | requires_grad: False
# Layer: layer2.7.conv1.weight | requires_grad: False
# Layer: layer2.7.bn1.weight | requires_grad: False
# Layer: layer2.7.bn1.bias | requires_grad: False
# Layer: layer2.7.conv2.weight | requires_grad: False
# Layer: layer2.7.bn2.weight | requires_grad: False
# Layer: layer2.7.bn2.bias | requires_grad: False
# Layer: layer2.7.conv3.weight | requires_grad: False
# Layer: layer2.7.bn3.weight | requires_grad: False
# Layer: layer2.7.bn3.bias | requires_grad: False
# Layer: layer3.0.conv1.weight | requires_grad: False
# Layer: layer3.0.bn1.weight | requires_grad: False
# Layer: layer3.0.bn1.bias | requires_grad: False
# Layer: layer3.0.conv2.weight | requires_grad: False
# Layer: layer3.0.bn2.weight | requires_grad: False
# Layer: layer3.0.bn2.bias | requires_grad: False
# Layer: layer3.0.conv3.weight | requires_grad: False
# Layer: layer3.0.bn3.weight | requires_grad: False
# Layer: layer3.0.bn3.bias | requires_grad: False
# Layer: layer3.0.downsample.0.weight | requires_grad: False
# Layer: layer3.0.downsample.1.weight | requires_grad: False
# Layer: layer3.0.downsample.1.bias | requires_grad: False
# Layer: layer3.1.conv1.weight | requires_grad: False
# Layer: layer3.1.bn1.weight | requires_grad: False
# Layer: layer3.1.bn1.bias | requires_grad: False
# Layer: layer3.1.conv2.weight | requires_grad: False
# Layer: layer3.1.bn2.weight | requires_grad: False
# Layer: layer3.1.bn2.bias | requires_grad: False
# Layer: layer3.1.conv3.weight | requires_grad: False
# Layer: layer3.1.bn3.weight | requires_grad: False
# Layer: layer3.1.bn3.bias | requires_grad: False
# Layer: layer3.2.conv1.weight | requires_grad: False
# Layer: layer3.2.bn1.weight | requires_grad: False
# Layer: layer3.2.bn1.bias | requires_grad: False
# Layer: layer3.2.conv2.weight | requires_grad: False
# Layer: layer3.2.bn2.weight | requires_grad: False
# Layer: layer3.2.bn2.bias | requires_grad: False
# Layer: layer3.2.conv3.weight | requires_grad: False
# Layer: layer3.2.bn3.weight | requires_grad: False
# Layer: layer3.2.bn3.bias | requires_grad: False
# Layer: layer3.3.conv1.weight | requires_grad: False
# Layer: layer3.3.bn1.weight | requires_grad: False
# Layer: layer3.3.bn1.bias | requires_grad: False
# Layer: layer3.3.conv2.weight | requires_grad: False
# Layer: layer3.3.bn2.weight | requires_grad: False
# Layer: layer3.3.bn2.bias | requires_grad: False
# Layer: layer3.3.conv3.weight | requires_grad: False
# Layer: layer3.3.bn3.weight | requires_grad: False
# Layer: layer3.3.bn3.bias | requires_grad: False
# Layer: layer3.4.conv1.weight | requires_grad: False
# Layer: layer3.4.bn1.weight | requires_grad: False
# Layer: layer3.4.bn1.bias | requires_grad: False
# Layer: layer3.4.conv2.weight | requires_grad: False
# Layer: layer3.4.bn2.weight | requires_grad: False
# Layer: layer3.4.bn2.bias | requires_grad: False
# Layer: layer3.4.conv3.weight | requires_grad: False
# Layer: layer3.4.bn3.weight | requires_grad: False
# Layer: layer3.4.bn3.bias | requires_grad: False
# Layer: layer3.5.conv1.weight | requires_grad: False
# Layer: layer3.5.bn1.weight | requires_grad: False
# Layer: layer3.5.bn1.bias | requires_grad: False
# Layer: layer3.5.conv2.weight | requires_grad: False
# Layer: layer3.5.bn2.weight | requires_grad: False
# Layer: layer3.5.bn2.bias | requires_grad: False
# Layer: layer3.5.conv3.weight | requires_grad: False
# Layer: layer3.5.bn3.weight | requires_grad: False
# Layer: layer3.5.bn3.bias | requires_grad: False
# Layer: layer3.6.conv1.weight | requires_grad: False
# Layer: layer3.6.bn1.weight | requires_grad: False
# Layer: layer3.6.bn1.bias | requires_grad: False
# Layer: layer3.6.conv2.weight | requires_grad: False
# Layer: layer3.6.bn2.weight | requires_grad: False
# Layer: layer3.6.bn2.bias | requires_grad: False
# Layer: layer3.6.conv3.weight | requires_grad: False
# Layer: layer3.6.bn3.weight | requires_grad: False
# Layer: layer3.6.bn3.bias | requires_grad: False
# Layer: layer3.7.conv1.weight | requires_grad: False
# Layer: layer3.7.bn1.weight | requires_grad: False
# Layer: layer3.7.bn1.bias | requires_grad: False
# Layer: layer3.7.conv2.weight | requires_grad: False
# Layer: layer3.7.bn2.weight | requires_grad: False
# Layer: layer3.7.bn2.bias | requires_grad: False
# Layer: layer3.7.conv3.weight | requires_grad: False
# Layer: layer3.7.bn3.weight | requires_grad: False
# Layer: layer3.7.bn3.bias | requires_grad: False
# Layer: layer3.8.conv1.weight | requires_grad: False
# Layer: layer3.8.bn1.weight | requires_grad: False
# Layer: layer3.8.bn1.bias | requires_grad: False
# Layer: layer3.8.conv2.weight | requires_grad: False
# Layer: layer3.8.bn2.weight | requires_grad: False
# Layer: layer3.8.bn2.bias | requires_grad: False
# Layer: layer3.8.conv3.weight | requires_grad: False
# Layer: layer3.8.bn3.weight | requires_grad: False
# Layer: layer3.8.bn3.bias | requires_grad: False
# Layer: layer3.9.conv1.weight | requires_grad: False
# Layer: layer3.9.bn1.weight | requires_grad: False
# Layer: layer3.9.bn1.bias | requires_grad: False
# Layer: layer3.9.conv2.weight | requires_grad: False
# Layer: layer3.9.bn2.weight | requires_grad: False
# Layer: layer3.9.bn2.bias | requires_grad: False
# Layer: layer3.9.conv3.weight | requires_grad: False
# Layer: layer3.9.bn3.weight | requires_grad: False
# Layer: layer3.9.bn3.bias | requires_grad: False
# Layer: layer3.10.conv1.weight | requires_grad: False
# Layer: layer3.10.bn1.weight | requires_grad: False
# Layer: layer3.10.bn1.bias | requires_grad: False
# Layer: layer3.10.conv2.weight | requires_grad: False
# Layer: layer3.10.bn2.weight | requires_grad: False
# Layer: layer3.10.bn2.bias | requires_grad: False
# Layer: layer3.10.conv3.weight | requires_grad: False
# Layer: layer3.10.bn3.weight | requires_grad: False
# Layer: layer3.10.bn3.bias | requires_grad: False
# Layer: layer3.11.conv1.weight | requires_grad: False
# Layer: layer3.11.bn1.weight | requires_grad: False
# Layer: layer3.11.bn1.bias | requires_grad: False
# Layer: layer3.11.conv2.weight | requires_grad: False
# Layer: layer3.11.bn2.weight | requires_grad: False
# Layer: layer3.11.bn2.bias | requires_grad: False
# Layer: layer3.11.conv3.weight | requires_grad: False
# Layer: layer3.11.bn3.weight | requires_grad: False
# Layer: layer3.11.bn3.bias | requires_grad: False
# Layer: layer3.12.conv1.weight | requires_grad: False
# Layer: layer3.12.bn1.weight | requires_grad: False
# Layer: layer3.12.bn1.bias | requires_grad: False
# Layer: layer3.12.conv2.weight | requires_grad: False
# Layer: layer3.12.bn2.weight | requires_grad: False
# Layer: layer3.12.bn2.bias | requires_grad: False
# Layer: layer3.12.conv3.weight | requires_grad: False
# Layer: layer3.12.bn3.weight | requires_grad: False
# Layer: layer3.12.bn3.bias | requires_grad: False
# Layer: layer3.13.conv1.weight | requires_grad: False
# Layer: layer3.13.bn1.weight | requires_grad: False
# Layer: layer3.13.bn1.bias | requires_grad: False
# Layer: layer3.13.conv2.weight | requires_grad: False
# Layer: layer3.13.bn2.weight | requires_grad: False
# Layer: layer3.13.bn2.bias | requires_grad: False
# Layer: layer3.13.conv3.weight | requires_grad: False
# Layer: layer3.13.bn3.weight | requires_grad: False
# Layer: layer3.13.bn3.bias | requires_grad: False
# Layer: layer3.14.conv1.weight | requires_grad: False
# Layer: layer3.14.bn1.weight | requires_grad: False
# Layer: layer3.14.bn1.bias | requires_grad: False
# Layer: layer3.14.conv2.weight | requires_grad: False
# Layer: layer3.14.bn2.weight | requires_grad: False
# Layer: layer3.14.bn2.bias | requires_grad: False
# Layer: layer3.14.conv3.weight | requires_grad: False
# Layer: layer3.14.bn3.weight | requires_grad: False
# Layer: layer3.14.bn3.bias | requires_grad: False
# Layer: layer3.15.conv1.weight | requires_grad: False
# Layer: layer3.15.bn1.weight | requires_grad: False
# Layer: layer3.15.bn1.bias | requires_grad: False
# Layer: layer3.15.conv2.weight | requires_grad: False
# Layer: layer3.15.bn2.weight | requires_grad: False
# Layer: layer3.15.bn2.bias | requires_grad: False
# Layer: layer3.15.conv3.weight | requires_grad: False
# Layer: layer3.15.bn3.weight | requires_grad: False
# Layer: layer3.15.bn3.bias | requires_grad: False
# Layer: layer3.16.conv1.weight | requires_grad: False
# Layer: layer3.16.bn1.weight | requires_grad: False
# Layer: layer3.16.bn1.bias | requires_grad: False
# Layer: layer3.16.conv2.weight | requires_grad: False
# Layer: layer3.16.bn2.weight | requires_grad: False
# Layer: layer3.16.bn2.bias | requires_grad: False
# Layer: layer3.16.conv3.weight | requires_grad: False
# Layer: layer3.16.bn3.weight | requires_grad: False
# Layer: layer3.16.bn3.bias | requires_grad: False
# Layer: layer3.17.conv1.weight | requires_grad: False
# Layer: layer3.17.bn1.weight | requires_grad: False
# Layer: layer3.17.bn1.bias | requires_grad: False
# Layer: layer3.17.conv2.weight | requires_grad: False
# Layer: layer3.17.bn2.weight | requires_grad: False
# Layer: layer3.17.bn2.bias | requires_grad: False
# Layer: layer3.17.conv3.weight | requires_grad: False
# Layer: layer3.17.bn3.weight | requires_grad: False
# Layer: layer3.17.bn3.bias | requires_grad: False
# Layer: layer3.18.conv1.weight | requires_grad: False
# Layer: layer3.18.bn1.weight | requires_grad: False
# Layer: layer3.18.bn1.bias | requires_grad: False
# Layer: layer3.18.conv2.weight | requires_grad: False
# Layer: layer3.18.bn2.weight | requires_grad: False
# Layer: layer3.18.bn2.bias | requires_grad: False
# Layer: layer3.18.conv3.weight | requires_grad: False
# Layer: layer3.18.bn3.weight | requires_grad: False
# Layer: layer3.18.bn3.bias | requires_grad: False
# Layer: layer3.19.conv1.weight | requires_grad: False
# Layer: layer3.19.bn1.weight | requires_grad: False
# Layer: layer3.19.bn1.bias | requires_grad: False
# Layer: layer3.19.conv2.weight | requires_grad: False
# Layer: layer3.19.bn2.weight | requires_grad: False
# Layer: layer3.19.bn2.bias | requires_grad: False
# Layer: layer3.19.conv3.weight | requires_grad: False
# Layer: layer3.19.bn3.weight | requires_grad: False
# Layer: layer3.19.bn3.bias | requires_grad: False
# Layer: layer3.20.conv1.weight | requires_grad: False
# Layer: layer3.20.bn1.weight | requires_grad: False
# Layer: layer3.20.bn1.bias | requires_grad: False
# Layer: layer3.20.conv2.weight | requires_grad: False
# Layer: layer3.20.bn2.weight | requires_grad: False
# Layer: layer3.20.bn2.bias | requires_grad: False
# Layer: layer3.20.conv3.weight | requires_grad: False
# Layer: layer3.20.bn3.weight | requires_grad: False
# Layer: layer3.20.bn3.bias | requires_grad: False
# Layer: layer3.21.conv1.weight | requires_grad: False
# Layer: layer3.21.bn1.weight | requires_grad: False
# Layer: layer3.21.bn1.bias | requires_grad: False
# Layer: layer3.21.conv2.weight | requires_grad: False
# Layer: layer3.21.bn2.weight | requires_grad: False
# Layer: layer3.21.bn2.bias | requires_grad: False
# Layer: layer3.21.conv3.weight | requires_grad: False
# Layer: layer3.21.bn3.weight | requires_grad: False
# Layer: layer3.21.bn3.bias | requires_grad: False
# Layer: layer3.22.conv1.weight | requires_grad: False
# Layer: layer3.22.bn1.weight | requires_grad: False
# Layer: layer3.22.bn1.bias | requires_grad: False
# Layer: layer3.22.conv2.weight | requires_grad: False
# Layer: layer3.22.bn2.weight | requires_grad: False
# Layer: layer3.22.bn2.bias | requires_grad: False
# Layer: layer3.22.conv3.weight | requires_grad: False
# Layer: layer3.22.bn3.weight | requires_grad: False
# Layer: layer3.22.bn3.bias | requires_grad: False
# Layer: layer3.23.conv1.weight | requires_grad: False
# Layer: layer3.23.bn1.weight | requires_grad: False
# Layer: layer3.23.bn1.bias | requires_grad: False
# Layer: layer3.23.conv2.weight | requires_grad: False
# Layer: layer3.23.bn2.weight | requires_grad: False
# Layer: layer3.23.bn2.bias | requires_grad: False
# Layer: layer3.23.conv3.weight | requires_grad: False
# Layer: layer3.23.bn3.weight | requires_grad: False
# Layer: layer3.23.bn3.bias | requires_grad: False
# Layer: layer3.24.conv1.weight | requires_grad: False
# Layer: layer3.24.bn1.weight | requires_grad: False
# Layer: layer3.24.bn1.bias | requires_grad: False
# Layer: layer3.24.conv2.weight | requires_grad: False
# Layer: layer3.24.bn2.weight | requires_grad: False
# Layer: layer3.24.bn2.bias | requires_grad: False
# Layer: layer3.24.conv3.weight | requires_grad: False
# Layer: layer3.24.bn3.weight | requires_grad: False
# Layer: layer3.24.bn3.bias | requires_grad: False
# Layer: layer3.25.conv1.weight | requires_grad: False
# Layer: layer3.25.bn1.weight | requires_grad: False
# Layer: layer3.25.bn1.bias | requires_grad: False
# Layer: layer3.25.conv2.weight | requires_grad: False
# Layer: layer3.25.bn2.weight | requires_grad: False
# Layer: layer3.25.bn2.bias | requires_grad: False
# Layer: layer3.25.conv3.weight | requires_grad: False
# Layer: layer3.25.bn3.weight | requires_grad: False
# Layer: layer3.25.bn3.bias | requires_grad: False
# Layer: layer3.26.conv1.weight | requires_grad: False
# Layer: layer3.26.bn1.weight | requires_grad: False
# Layer: layer3.26.bn1.bias | requires_grad: False
# Layer: layer3.26.conv2.weight | requires_grad: False
# Layer: layer3.26.bn2.weight | requires_grad: False
# Layer: layer3.26.bn2.bias | requires_grad: False
# Layer: layer3.26.conv3.weight | requires_grad: False
# Layer: layer3.26.bn3.weight | requires_grad: False
# Layer: layer3.26.bn3.bias | requires_grad: False
# Layer: layer3.27.conv1.weight | requires_grad: False
# Layer: layer3.27.bn1.weight | requires_grad: False
# Layer: layer3.27.bn1.bias | requires_grad: False
# Layer: layer3.27.conv2.weight | requires_grad: False
# Layer: layer3.27.bn2.weight | requires_grad: False
# Layer: layer3.27.bn2.bias | requires_grad: False
# Layer: layer3.27.conv3.weight | requires_grad: False
# Layer: layer3.27.bn3.weight | requires_grad: False
# Layer: layer3.27.bn3.bias | requires_grad: False
# Layer: layer3.28.conv1.weight | requires_grad: False
# Layer: layer3.28.bn1.weight | requires_grad: False
# Layer: layer3.28.bn1.bias | requires_grad: False
# Layer: layer3.28.conv2.weight | requires_grad: False
# Layer: layer3.28.bn2.weight | requires_grad: False
# Layer: layer3.28.bn2.bias | requires_grad: False
# Layer: layer3.28.conv3.weight | requires_grad: False
# Layer: layer3.28.bn3.weight | requires_grad: False
# Layer: layer3.28.bn3.bias | requires_grad: False
# Layer: layer3.29.conv1.weight | requires_grad: False
# Layer: layer3.29.bn1.weight | requires_grad: False
# Layer: layer3.29.bn1.bias | requires_grad: False
# Layer: layer3.29.conv2.weight | requires_grad: False
# Layer: layer3.29.bn2.weight | requires_grad: False
# Layer: layer3.29.bn2.bias | requires_grad: False
# Layer: layer3.29.conv3.weight | requires_grad: False
# Layer: layer3.29.bn3.weight | requires_grad: False
# Layer: layer3.29.bn3.bias | requires_grad: False
# Layer: layer3.30.conv1.weight | requires_grad: False
# Layer: layer3.30.bn1.weight | requires_grad: False
# Layer: layer3.30.bn1.bias | requires_grad: False
# Layer: layer3.30.conv2.weight | requires_grad: False
# Layer: layer3.30.bn2.weight | requires_grad: False
# Layer: layer3.30.bn2.bias | requires_grad: False
# Layer: layer3.30.conv3.weight | requires_grad: False
# Layer: layer3.30.bn3.weight | requires_grad: False
# Layer: layer3.30.bn3.bias | requires_grad: False
# Layer: layer3.31.conv1.weight | requires_grad: False
# Layer: layer3.31.bn1.weight | requires_grad: False
# Layer: layer3.31.bn1.bias | requires_grad: False
# Layer: layer3.31.conv2.weight | requires_grad: False
# Layer: layer3.31.bn2.weight | requires_grad: False
# Layer: layer3.31.bn2.bias | requires_grad: False
# Layer: layer3.31.conv3.weight | requires_grad: False
# Layer: layer3.31.bn3.weight | requires_grad: False
# Layer: layer3.31.bn3.bias | requires_grad: False
# Layer: layer3.32.conv1.weight | requires_grad: False
# Layer: layer3.32.bn1.weight | requires_grad: False
# Layer: layer3.32.bn1.bias | requires_grad: False
# Layer: layer3.32.conv2.weight | requires_grad: False
# Layer: layer3.32.bn2.weight | requires_grad: False
# Layer: layer3.32.bn2.bias | requires_grad: False
# Layer: layer3.32.conv3.weight | requires_grad: False
# Layer: layer3.32.bn3.weight | requires_grad: False
# Layer: layer3.32.bn3.bias | requires_grad: False
# Layer: layer3.33.conv1.weight | requires_grad: False
# Layer: layer3.33.bn1.weight | requires_grad: False
# Layer: layer3.33.bn1.bias | requires_grad: False
# Layer: layer3.33.conv2.weight | requires_grad: False
# Layer: layer3.33.bn2.weight | requires_grad: False
# Layer: layer3.33.bn2.bias | requires_grad: False
# Layer: layer3.33.conv3.weight | requires_grad: False
# Layer: layer3.33.bn3.weight | requires_grad: False
# Layer: layer3.33.bn3.bias | requires_grad: False
# Layer: layer3.34.conv1.weight | requires_grad: False
# Layer: layer3.34.bn1.weight | requires_grad: False
# Layer: layer3.34.bn1.bias | requires_grad: False
# Layer: layer3.34.conv2.weight | requires_grad: False
# Layer: layer3.34.bn2.weight | requires_grad: False
# Layer: layer3.34.bn2.bias | requires_grad: False
# Layer: layer3.34.conv3.weight | requires_grad: False
# Layer: layer3.34.bn3.weight | requires_grad: False
# Layer: layer3.34.bn3.bias | requires_grad: False
# Layer: layer3.35.conv1.weight | requires_grad: False
# Layer: layer3.35.bn1.weight | requires_grad: False
# Layer: layer3.35.bn1.bias | requires_grad: False
# Layer: layer3.35.conv2.weight | requires_grad: False
# Layer: layer3.35.bn2.weight | requires_grad: False
# Layer: layer3.35.bn2.bias | requires_grad: False
# Layer: layer3.35.conv3.weight | requires_grad: False
# Layer: layer3.35.bn3.weight | requires_grad: False
# Layer: layer3.35.bn3.bias | requires_grad: False
# Layer: layer4.0.conv1.weight | requires_grad: False
# Layer: layer4.0.bn1.weight | requires_grad: False
# Layer: layer4.0.bn1.bias | requires_grad: False
# Layer: layer4.0.conv2.weight | requires_grad: False
# Layer: layer4.0.bn2.weight | requires_grad: False
# Layer: layer4.0.bn2.bias | requires_grad: False
# Layer: layer4.0.conv3.weight | requires_grad: False
# Layer: layer4.0.bn3.weight | requires_grad: False
# Layer: layer4.0.bn3.bias | requires_grad: False
# Layer: layer4.0.downsample.0.weight | requires_grad: False
# Layer: layer4.0.downsample.1.weight | requires_grad: False
# Layer: layer4.0.downsample.1.bias | requires_grad: False
# Layer: layer4.1.conv1.weight | requires_grad: False
# Layer: layer4.1.bn1.weight | requires_grad: False
# Layer: layer4.1.bn1.bias | requires_grad: False
# Layer: layer4.1.conv2.weight | requires_grad: False
# Layer: layer4.1.bn2.weight | requires_grad: False
# Layer: layer4.1.bn2.bias | requires_grad: False
# Layer: layer4.1.conv3.weight | requires_grad: False
# Layer: layer4.1.bn3.weight | requires_grad: False
# Layer: layer4.1.bn3.bias | requires_grad: False
# Layer: layer4.2.conv1.weight | requires_grad: False
# Layer: layer4.2.bn1.weight | requires_grad: False
# Layer: layer4.2.bn1.bias | requires_grad: False
# Layer: layer4.2.conv2.weight | requires_grad: False
# Layer: layer4.2.bn2.weight | requires_grad: False
# Layer: layer4.2.bn2.bias | requires_grad: False
# Layer: layer4.2.conv3.weight | requires_grad: False
# Layer: layer4.2.bn3.weight | requires_grad: False
# Layer: layer4.2.bn3.bias | requires_grad: False
# Layer: fc.weight | requires_grad: True
# Layer: fc.bias | requires_grad: True

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, ResNet152.parameters()), lr=0.00001)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# %%
DEVICE = "mps" if torch.backends.mps.is_available() else "cpu"
DEVICE
# Out:
# 'mps'

# %%
# !pip install nbimporter
# Out:
# Collecting nbimporter
#   Downloading nbimporter-0.3.4-py3-none-any.whl.metadata (252 bytes)
# Downloading nbimporter-0.3.4-py3-none-any.whl (4.9 kB)
# Installing collected packages: nbimporter
# Successfully installed nbimporter-0.3.4

# %%
import nbimporter
from ResNet import train, evaluate, train_baseline

# %%
fine_tuned = train_baseline(model=ResNet152.to("mps"),
                            train_dataloader=train_dataloader,
                            val_dataloader=val_dataloader,
                            optimizer=optimizer,
                            loss_fn=loss_fn,
                            num_epochs=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 fine_tuned = train_baseline(model=ResNet152.to("mps"),
#       2                             train_dataloader=train_dataloader,
#       3                             val_dataloader=val_dataloader,
#       4                             optimizer=optimizer,
#       5                             loss_fn=loss_fn,
#       6                             num_epochs=3)
#
# File ~/pytorch/ResNet/ResNet.ipynb:12, in train_baseline(model, train_dataloader, val_dataloader, optimizer, loss_fn, num_epochs)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 44,
#       6    "id": "0efd8ea0-c2cb-44eb-9458-84fc3592a6b7",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import copy\n",
#      11     "import time\n",
# ---> 12     "import os\n",
#      13     "import torch\n",
#      14     "from torch import nn\n",
#      15     "import torchvision\n",
#      16     "from torchvision import transforms\n",
#      17     "from torchvision import datasets\n",
#      18     "from torchvision.datasets import ImageFolder\n",
#      19     "from torch.utils.data import DataLoader"
#      20    ]
#      21   },
#      22   {
#      23    "cell_type": "markdown",
#      24    "id": "b3d3ba30-8d22-409b-9111-50e43d34e268",
#      25    "metadata": {},
#      26    "source": [
#      27     "# Dataset"
#      28    ]
#      29   },
#      30   {
#      31    "cell_type": "code",
#      32    "execution_count": 63,
#      33    "id": "76782785-eda5-49e9-84dd-41f8a747f931",
#      34    "metadata": {},
#      35    "outputs": [],
#      36    "source": [
#      37     "base_dir = r\"/Users/h383kim/pytorch/AlexNet/splitted\"\n",
#      38     "train_dir = os.path.join(base_dir, 'train')\n",
#      39     "val_dir = os.path.join(base_dir, 'val')\n",
#      40     "test_dir = os.path.join(base_dir, 'test')\n",
#      41     "\n",
#      42     "img_transform = transforms.Compose([\n",
#      43     "    transforms.Resize(size=(224, 224)),\n",
#      44     "    transforms.RandomHorizontalFlip(),\n",
#      45     "    transforms.ToTensor(),\n",
#      46     "    transforms.Normalize(mean=[0.5108, 0.4829, 0.3989], std=[0.2632, 0.2587, 0.2706])\n",
#      47     "])\n",
#      48     "\n",
#      49     "train_dataset = ImageFolder(root=train_dir,\n",
#      50     "                            transform=img_transform)\n",
#      51     "val_dataset = ImageFolder(root=val_dir,\n",
#      52     "                          transform=img_transform)\n",
#      53     "test_dataset = ImageFolder(root=test_dir,\n",
#      54     "                           transform=img_transform)\n",
#      55     "\n",
#      56     "BATCH_SIZE = 32\n",
#      57     "\n",
#      58     "train_dataloader = DataLoader(dataset=train_dataset,\n",
#      59     "                              batch_size=BATCH_SIZE,\n",
#      60     "                              shuffle=True,\n",
#      61     "                              num_workers=os.cpu_count())\n",
#      62     "val_dataloader = DataLoader(dataset=val_dataset,\n",
#      63     "                            batch_size=BATCH_SIZE,\n",
#      64     "                            shuffle=True,\n",
#      65     "                            num_workers=os.cpu_count())\n",
#      66     "test_dataloader = DataLoader(dataset=test_dataset,\n",
#      67     "                             batch_size=BATCH_SIZE,\n",
#      68     "                             shuffle=False,\n",
#      69     "                             num_workers=os.cpu_count())"
#      70    ]
#      71   },
#      72   {
#      73    "cell_type": "markdown",
#      74    "id": "5b2bbc38-2e45-4b74-8d5f-581c3e504aa4",
#      75    "metadata": {},
#      76    "source": [
#      77     "# Model"
#      78    ]
#      79   },
#      80   {
#      81    "cell_type": "code",
#      82    "execution_count": 46,
#      83    "id": "1c1de790-cfc4-46f8-83f4-aea06461fdb0",
#      84    "metadata": {},
#      85    "outputs": [],
#      86    "source": [
#      87     "ResNet_type = {\n",
#      88     "    \"ResNet18\"  : (\"Basic_Conv\", [2, 2, 2, 2]),\n",
#      89     "    \"ResNet34\"  : (\"Basic_Conv\", [3, 4, 6, 3]),\n",
#      90     "    \"ResNet50\"  : (\"BottleNeck\", [3, 4, 6, 3]),\n",
#      91     "    \"ResNet101\" : (\"BottleNeck\", [3, 4, 23, 3]),\n",
#      92     "    \"ResNet152\" : (\"BottleNeck\", [3, 8, 36, 3])\n",
#      93     "}"
#      94    ]
#      95   },
#      96   {
#      97    "cell_type": "code",
#      98    "execution_count": 47,
#      99    "id": "a0c0d3da-d342-41e9-a588-b29f3d444a5f",
#     100    "metadata": {},
#     101    "outputs": [],
#     102    "source": [
#     103     "class Basic_Conv(nn.Module):\n",
#     104     "    def __init__(self, in_channels, out_channels, stride):\n",
#     105     "        super().__init__()\n",
#     106     "\n",
#     107     "        \n",
#     108     "        self.conv1 = nn.Sequential(\n",
#     109     "            nn.Conv2d(in_channels=in_channels, out_channels=out_channels, kernel_size=(3, 3), stride=stride, padding=1, bias=False),\n",
#     110     "            nn.BatchNorm2d(out_channels),\n",
#     111     "            nn.ReLU()\n",
#     112     "        )\n",
#     113     "        \n",
#     114     "        self.conv2 = nn.Sequential(\n",
#     115     "            nn.Conv2d(in_channels=out_channels, out_channels=out_channels, kernel_size=(3, 3), stride=1, padding=1, bias=False),\n",
#     116     "            nn.BatchNorm2d(out_channels),\n",
#     117     "        )\n",
#     118     "\n",
#     119     "        self.shortcut = nn.Sequential()\n",
#     120     "\n",
#     121     "        if stride > 1:\n",
#     122     "        #if stride > 1 or in_channels != out_channels:\n",
#     123     "            self.shortcut = nn.Sequential(\n",
#     124     "                # Downsamples to match spatial dimensions and 1x1 projecion shortcut to match channels\n",
#     125     "                nn.Conv2d(in_channels=in_channels, out_channels=out_channels, kernel_size=(1, 1), stride=stride, bias=False),\n",
#     126     "                nn.BatchNorm2d(out_channels)\n",
#     127     "            )\n",
#     128     "\n",
#     129     "        self.relu = nn.ReLU()\n",
#     130     "    \n",
#     131     "    def forward(self, x):\n",
#     132     "        out = self.conv1(x)\n",
#     133     "        out = self.conv2(out)\n",
#     134     "        \n",
#     135     "        identity = self.shortcut(x)\n",
#     136     "        \n",
#     137     "        out = out + identity\n",
#     138     "        out = self.relu(out)\n",
#     139     "\n",
#     140     "        return out\n",
#     141     "        "
#     142    ]
#     143   },
#     144   {
#     145    "cell_type": "code",
#     146    "execution_count": 48,
#     147    "id": "c770dd37-5ca5-47cf-afb0-0c2134f33d16",
#     148    "metadata": {},
#     149    "outputs": [],
#     150    "source": [
#     151     "class BottleNeck(nn.Module):\n",
#     152     "    def __init__(self, in_channels, out_channels, stride):\n",
#     153     "        super().__init__()\n",
#     154     "\n",
#     155     "        self.out_mult = 4\n",
#     156     "\n",
#     157     "        self.conv = nn.Sequential(\n",
#     158     "            # 1 x 1 conv, dim reduction\n",
#     159     "            nn.Conv2d(in_channels=in_channels, out_channels=out_channels, kernel_size=(1, 1), bias=False),\n",
#     160     "            nn.BatchNorm2d(out_channels),\n",
#     161     "            nn.ReLU(),\n",
#     162     "            nn.Conv2d(in_channels=out_channels, out_channels=out_channels, kernel_size=(3, 3), stride=stride, padding=1, bias=False),\n",
#     163     "            nn.BatchNorm2d(out_channels),\n",
#     164     "            nn.ReLU(),\n",
#     165     "            nn.Conv2d(in_channels=out_channels, out_channels=out_channels*self.out_mult, kernel_size=(1, 1), bias=False),\n",
#     166     "            nn.BatchNorm2d(out_channels*self.out_mult)\n",
#     167     "        )\n",
#     168     "        \n",
#     169     "        self.shortcut = nn.Sequential()\n",
#     170     "\n",
#     171     "        if stride > 1 or in_channels != out_channels * self.out_mult:\n",
#     172     "            self.shortcut = nn.Sequential(\n",
#     173     "                nn.Conv2d(in_channels=in_channels, out_channels=out_channels*self.out_mult, stride=stride, kernel_size=(1, 1), bias=False),\n",
#     174     "                nn.BatchNorm2d(out_channels*self.out_mult)\n",
#     175     "            )\n",
#     176     "\n",
#     177     "        self.relu = nn.ReLU()\n",
#     178     "        \n",
#     179     "    def forward(self, x):\n",
#     180     "        out = self.conv(x)\n",
#     181     "        #print(out.shape)\n",
#     182     "        identity = self.shortcut(x)\n",
#     183     "        #print(identity.shape)\n",
#     184     "        out = out + identity\n",
#     185     "        out = self.relu(out)\n",
#     186     "\n",
#     187     "        return out"
#     188    ]
#     189   },
#     190   {
#     191    "cell_type": "code",
#     192    "execution_count": 49,
#     193    "id": "de636d28-802e-49e3-bfd3-e2f889f686c3",
#     194    "metadata": {},
#     195    "outputs": [],
#     196    "source": [
#     197     "class ResNet(nn.Module):\n",
#     198     "    def __init__(self, in_channels=3, num_classes=10, model=\"ResNet50\"):\n",
#     199     "        super().__init__()\n",
#     200     "        self.CHANNELS = 64\n",
#     201     "\n",
#     202     "        self.conv1 = nn.Sequential(\n",
#     203     "            nn.Conv2d(in_channels=in_channels, out_channels=64, kernel_size=(7, 7), stride=2, padding=3, bias=False),\n",
#     204     "            nn.BatchNorm2d(64),\n",
#     205     "            nn.ReLU(),\n",
#     206     "            nn.MaxPool2d(kernel_size=3, stride=2, padding=1)\n",
#     207     "        )\n",
#     208     "        self.conv2 = self._make_layers(ResNet_type[model][0], ResNet_type[model][1][0], 64, 1)\n",
#     209     "        self.conv3 = self._make_layers(ResNet_type[model][0], ResNet_type[model][1][1], 128, 2)\n",
#     210     "        self.conv4 = self._make_layers(ResNet_type[model][0], ResNet_type[model][1][2], 256, 2)\n",
#     211     "        self.conv5 = self._make_layers(ResNet_type[model][0], ResNet_type[model][1][3], 512, 2)\n",
#     212     "\n",
#     213     "        self.avg = nn.AdaptiveAvgPool2d((1, 1))\n",
#     214     "        self.OUTCHANNELS = 512 if ResNet_type[model][0] == \"Basic_Conv\" else 512*4\n",
#     215     "        \n",
#     216     "        self.fc = nn.Linear(self.OUTCHANNELS, num_classes) \n",
#     217     "\n",
#     218     "    def _make_layers(self, block, num_blocks, out_channels, stride):\n",
#     219     "        # Any spatial reduction (i.e stride > 1) is applied in the very first layer of the block only\n",
#     220     "        strides = [stride] + [1]*(num_blocks - 1) # len(strides) == num_blocks\n",
#     221     "        conv_blocks = []\n",
#     222     "        \n",
#     223     "        if block == \"Basic_Conv\":\n",
#     224     "            for stride in strides:\n",
#     225     "                conv_blocks.append(Basic_Conv(self.CHANNELS, out_channels, stride))\n",
#     226     "                self.CHANNELS = out_channels\n",
#     227     "        else:\n",
#     228     "            for stride in strides:\n",
#     229     "                conv_blocks.append(BottleNeck(self.CHANNELS, out_channels, stride))\n",
#     230     "                self.CHANNELS = out_channels * 4\n",
#     231     "\n",
#     232     "        return nn.Sequential(*conv_blocks)\n",
#     233     "        \n",
#     234     "    def forward(self, x):\n",
#     235     "        #print(\"--------conv1----------\")\n",
#     236     "        x = self.conv1(x)\n",
#     237     "        #print(\"--------conv2----------\")\n",
#     238     "        x = self.conv2(x)\n",
#     239     "        #print(\"--------conv3----------\")\n",
#     240     "        x = self.conv3(x)\n",
#     241     "        #print(\"--------conv4----------\")\n",
#     242     "        x = self.conv4(x)\n",
#     243     "        #print(\"--------conv5----------\")\n",
#     244     "        x = self.conv5(x)\n",
#     245     "        x = self.avg(x)\n",
#     246     "        # Flatten\n",
#     247     "        x = x.view(x.size(0), -1)\n",
#     248     "        x = self.fc(x)\n",
#     249     "        \n",
#     250     "        return x"
#     251    ]
#     252   },
#     253   {
#     254    "cell_type": "code",
#     255    "execution_count": null,
#     256    "id": "7512f61b-2837-45c4-b590-e32a97343da1",
#     257    "metadata": {},
#     258    "outputs": [],
#     259    "source": [
#     260     "from torchsummary import summary\n",
#     261     "Res = ResNet(model=\"ResNet34\")\n",
#     262     "summary(Res.to(\"cpu\"), input_size=(3, 224, 224), device=\"cpu\")"
#     263    ]
#     264   },
#     265   {
#     266    "cell_type": "code",
#     267    "execution_count": 33,
#     268    "id": "af00a3ee-ad26-4dae-bb1b-4363f34bba84",
#     269    "metadata": {},
#     270    "outputs": [
#     271     {
#     272      "name": "stdout",
#     273      "output_type": "stream",
#     274      "text": [
#     275       "----------------------------------------------------------------\n",
#     276       "        Layer (type)               Output Shape         Param #\n",
#     277       "================================================================\n",
#     278       "            Conv2d-1         [-1, 64, 112, 112]           9,408\n",
#     279       "       BatchNorm2d-2         [-1, 64, 112, 112]             128\n",
#     280       "              ReLU-3         [-1, 64, 112, 112]               0\n",
#     281       "         MaxPool2d-4           [-1, 64, 56, 56]               0\n",
#     282       "            Conv2d-5           [-1, 64, 56, 56]           4,096\n",
#     283       "       BatchNorm2d-6           [-1, 64, 56, 56]             128\n",
#     284       "              ReLU-7           [-1, 64, 56, 56]               0\n",
#     285       "            Conv2d-8           [-1, 64, 56, 56]          36,864\n",
#     286       "       BatchNorm2d-9           [-1, 64, 56, 56]             128\n",
#     287       "             ReLU-10           [-1, 64, 56, 56]               0\n",
#     288       "           Conv2d-11          [-1, 256, 56, 56]          16,384\n",
#     289       "      BatchNorm2d-12          [-1, 256, 56, 56]             512\n",
#     290       "           Conv2d-13          [-1, 256, 56, 56]          16,384\n",
#     291       "      BatchNorm2d-14          [-1, 256, 56, 56]             512\n",
#     292       "             ReLU-15          [-1, 256, 56, 56]               0\n",
#     293       "       BottleNeck-16          [-1, 256, 56, 56]               0\n",
#     294       "           Conv2d-17           [-1, 64, 56, 56]          16,384\n",
#     295       "      BatchNorm2d-18           [-1, 64, 56, 56]             128\n",
#     296       "             ReLU-19           [-1, 64, 56, 56]               0\n",
#     297       "           Conv2d-20           [-1, 64, 56, 56]          36,864\n",
#     298       "      BatchNorm2d-21           [-1, 64, 56, 56]             128\n",
#     299       "             ReLU-22           [-1, 64, 56, 56]               0\n",
#     300       "           Conv2d-23          [-1, 256, 56, 56]          16,384\n",
#     301       "      BatchNorm2d-24          [-1, 256, 56, 56]             512\n",
#     302       "             ReLU-25          [-1, 256, 56, 56]               0\n",
#     303       "       BottleNeck-26          [-1, 256, 56, 56]               0\n",
#     304       "           Conv2d-27           [-1, 64, 56, 56]          16,384\n",
#     305       "      BatchNorm2d-28           [-1, 64, 56, 56]             128\n",
#     306       "             ReLU-29           [-1, 64, 56, 56]               0\n",
#     307       "           Conv2d-30           [-1, 64, 56, 56]          36,864\n",
#     308       "      BatchNorm2d-31           [-1, 64, 56, 56]             128\n",
#     309       "             ReLU-32           [-1, 64, 56, 56]               0\n",
#     310       "           Conv2d-33          [-1, 256, 56, 56]          16,384\n",
#     311       "      BatchNorm2d-34          [-1, 256, 56, 56]             512\n",
#     312       "             ReLU-35          [-1, 256, 56, 56]               0\n",
#     313       "       BottleNeck-36          [-1, 256, 56, 56]               0\n",
#     314       "           Conv2d-37          [-1, 128, 56, 56]          32,768\n",
#     315       "      BatchNorm2d-38          [-1, 128, 56, 56]             256\n",
#     316       "             ReLU-39          [-1, 128, 56, 56]               0\n",
#     317       "           Conv2d-40          [-1, 128, 28, 28]         147,456\n",
#     318       "      BatchNorm2d-41          [-1, 128, 28, 28]             256\n",
#     319       "             ReLU-42          [-1, 128, 28, 28]               0\n",
#     320       "           Conv2d-43          [-1, 512, 28, 28]          65,536\n",
#     321       "      BatchNorm2d-44          [-1, 512, 28, 28]           1,024\n",
#     322       "           Conv2d-45          [-1, 512, 28, 28]         131,072\n",
#     323       "      BatchNorm2d-46          [-1, 512, 28, 28]           1,024\n",
#     324       "             ReLU-47          [-1, 512, 28, 28]               0\n",
#     325       "       BottleNeck-48          [-1, 512, 28, 28]               0\n",
#     326       "           Conv2d-49          [-1, 128, 28, 28]          65,536\n",
#     327       "      BatchNorm2d-50          [-1, 128, 28, 28]             256\n",
#     328       "             ReLU-51          [-1, 128, 28, 28]               0\n",
#     329       "           Conv2d-52          [-1, 128, 28, 28]         147,456\n",
#     330       "      BatchNorm2d-53          [-1, 128, 28, 28]             256\n",
#     331       "             ReLU-54          [-1, 128, 28, 28]               0\n",
#     332       "           Conv2d-55          [-1, 512, 28, 28]          65,536\n",
#     333       "      BatchNorm2d-56          [-1, 512, 28, 28]           1,024\n",
#     334       "             ReLU-57          [-1, 512, 28, 28]               0\n",
#     335       "       BottleNeck-58          [-1, 512, 28, 28]               0\n",
#     336       "           Conv2d-59          [-1, 128, 28, 28]          65,536\n",
#     337       "      BatchNorm2d-60          [-1, 128, 28, 28]             256\n",
#     338       "             ReLU-61          [-1, 128, 28, 28]               0\n",
#     339       "           Conv2d-62          [-1, 128, 28, 28]         147,456\n",
#     340       "      BatchNorm2d-63          [-1, 128, 28, 28]             256\n",
#     341       "             ReLU-64          [-1, 128, 28, 28]               0\n",
#     342       "           Conv2d-65          [-1, 512, 28, 28]          65,536\n",
#     343       "      BatchNorm2d-66          [-1, 512, 28, 28]           1,024\n",
#     344       "             ReLU-67          [-1, 512, 28, 28]               0\n",
#     345       "       BottleNeck-68          [-1, 512, 28, 28]               0\n",
#     346       "           Conv2d-69          [-1, 128, 28, 28]          65,536\n",
#     347       "      BatchNorm2d-70          [-1, 128, 28, 28]             256\n",
#     348       "             ReLU-71          [-1, 128, 28, 28]               0\n",
#     349       "           Conv2d-72          [-1, 128, 28, 28]         147,456\n",
#     350       "      BatchNorm2d-73          [-1, 128, 28, 28]             256\n",
#     351       "             ReLU-74          [-1, 128, 28, 28]               0\n",
#     352       "           Conv2d-75          [-1, 512, 28, 28]          65,536\n",
#     353       "      BatchNorm2d-76          [-1, 512, 28, 28]           1,024\n",
#     354       "             ReLU-77          [-1, 512, 28, 28]               0\n",
#     355       "       BottleNeck-78          [-1, 512, 28, 28]               0\n",
#     356       "           Conv2d-79          [-1, 256, 28, 28]         131,072\n",
#     357       "      BatchNorm2d-80          [-1, 256, 28, 28]             512\n",
#     358       "             ReLU-81          [-1, 256, 28, 28]               0\n",
#     359       "           Conv2d-82          [-1, 256, 14, 14]         589,824\n",
#     360       "      BatchNorm2d-83          [-1, 256, 14, 14]             512\n",
#     361       "             ReLU-84          [-1, 256, 14, 14]               0\n",
#     362       "           Conv2d-85         [-1, 1024, 14, 14]         262,144\n",
#     363       "      BatchNorm2d-86         [-1, 1024, 14, 14]           2,048\n",
#     364       "           Conv2d-87         [-1, 1024, 14, 14]         524,288\n",
#     365       "      BatchNorm2d-88         [-1, 1024, 14, 14]           2,048\n",
#     366       "             ReLU-89         [-1, 1024, 14, 14]               0\n",
#     367       "       BottleNeck-90         [-1, 1024, 14, 14]               0\n",
#     368       "           Conv2d-91          [-1, 256, 14, 14]         262,144\n",
#     369       "      BatchNorm2d-92          [-1, 256, 14, 14]             512\n",
#     370       "             ReLU-93          [-1, 256, 14, 14]               0\n",
#     371       "           Conv2d-94          [-1, 256, 14, 14]         589,824\n",
#     372       "      BatchNorm2d-95          [-1, 256, 14, 14]             512\n",
#     373       "             ReLU-96          [-1, 256, 14, 14]               0\n",
#     374       "           Conv2d-97         [-1, 1024, 14, 14]         262,144\n",
#     375       "      BatchNorm2d-98         [-1, 1024, 14, 14]           2,048\n",
#     376       "             ReLU-99         [-1, 1024, 14, 14]               0\n",
#     377       "      BottleNeck-100         [-1, 1024, 14, 14]               0\n",
#     378       "          Conv2d-101          [-1, 256, 14, 14]         262,144\n",
#     379       "     BatchNorm2d-102          [-1, 256, 14, 14]             512\n",
#     380       "            ReLU-103          [-1, 256, 14, 14]               0\n",
#     381       "          Conv2d-104          [-1, 256, 14, 14]         589,824\n",
#     382       "     BatchNorm2d-105          [-1, 256, 14, 14]             512\n",
#     383       "            ReLU-106          [-1, 256, 14, 14]               0\n",
#     384       "          Conv2d-107         [-1, 1024, 14, 14]         262,144\n",
#     385       "     BatchNorm2d-108         [-1, 1024, 14, 14]           2,048\n",
#     386       "            ReLU-109         [-1, 1024, 14, 14]               0\n",
#     387       "      BottleNeck-110         [-1, 1024, 14, 14]               0\n",
#     388       "          Conv2d-111          [-1, 256, 14, 14]         262,144\n",
#     389       "     BatchNorm2d-112          [-1, 256, 14, 14]             512\n",
#     390       "            ReLU-113          [-1, 256, 14, 14]               0\n",
#     391       "          Conv2d-114          [-1, 256, 14, 14]         589,824\n",
#     392       "     BatchNorm2d-115          [-1, 256, 14, 14]             512\n",
#     393       "            ReLU-116          [-1, 256, 14, 14]               0\n",
#     394       "          Conv2d-117         [-1, 1024, 14, 14]         262,144\n",
#     395       "     BatchNorm2d-118         [-1, 1024, 14, 14]           2,048\n",
#     396       "            ReLU-119         [-1, 1024, 14, 14]               0\n",
#     397       "      BottleNeck-120         [-1, 1024, 14, 14]               0\n",
#     398       "          Conv2d-121          [-1, 256, 14, 14]         262,144\n",
#     399       "     BatchNorm2d-122          [-1, 256, 14, 14]             512\n",
#     400       "            ReLU-123          [-1, 256, 14, 14]               0\n",
#     401       "          Conv2d-124          [-1, 256, 14, 14]         589,824\n",
#     402       "     BatchNorm2d-125          [-1, 256, 14, 14]             512\n",
#     403       "            ReLU-126          [-1, 256, 14, 14]               0\n",
#     404       "          Conv2d-127         [-1, 1024, 14, 14]         262,144\n",
#     405       "     BatchNorm2d-128         [-1, 1024, 14, 14]           2,048\n",
#     406       "            ReLU-129         [-1, 1024, 14, 14]               0\n",
#     407       "      BottleNeck-130         [-1, 1024, 14, 14]               0\n",
#     408       "          Conv2d-131          [-1, 256, 14, 14]         262,144\n",
#     409       "     BatchNorm2d-132          [-1, 256, 14, 14]             512\n",
#     410       "            ReLU-133          [-1, 256, 14, 14]               0\n",
#     411       "          Conv2d-134          [-1, 256, 14, 14]         589,824\n",
#     412       "     BatchNorm2d-135          [-1, 256, 14, 14]             512\n",
#     413       "            ReLU-136          [-1, 256, 14, 14]               0\n",
#     414       "          Conv2d-137         [-1, 1024, 14, 14]         262,144\n",
#     415       "     BatchNorm2d-138         [-1, 1024, 14, 14]           2,048\n",
#     416       "            ReLU-139         [-1, 1024, 14, 14]               0\n",
#     417       "      BottleNeck-140         [-1, 1024, 14, 14]               0\n",
#     418       "          Conv2d-141          [-1, 512, 14, 14]         524,288\n",
#     419       "     BatchNorm2d-142          [-1, 512, 14, 14]           1,024\n",
#     420       "            ReLU-143          [-1, 512, 14, 14]               0\n",
#     421       "          Conv2d-144            [-1, 512, 7, 7]       2,359,296\n",
#     422       "     BatchNorm2d-145            [-1, 512, 7, 7]           1,024\n",
#     423       "            ReLU-146            [-1, 512, 7, 7]               0\n",
#     424       "          Conv2d-147           [-1, 2048, 7, 7]       1,048,576\n",
#     425       "     BatchNorm2d-148           [-1, 2048, 7, 7]           4,096\n",
#     426       "          Conv2d-149           [-1, 2048, 7, 7]       2,097,152\n",
#     427       "     BatchNorm2d-150           [-1, 2048, 7, 7]           4,096\n",
#     428       "            ReLU-151           [-1, 2048, 7, 7]               0\n",
#     429       "      BottleNeck-152           [-1, 2048, 7, 7]               0\n",
#     430       "          Conv2d-153            [-1, 512, 7, 7]       1,048,576\n",
#     431       "     BatchNorm2d-154            [-1, 512, 7, 7]           1,024\n",
#     432       "            ReLU-155            [-1, 512, 7, 7]               0\n",
#     433       "          Conv2d-156            [-1, 512, 7, 7]       2,359,296\n",
#     434       "     BatchNorm2d-157            [-1, 512, 7, 7]           1,024\n",
#     435       "            ReLU-158            [-1, 512, 7, 7]               0\n",
#     436       "          Conv2d-159           [-1, 2048, 7, 7]       1,048,576\n",
#     437       "     BatchNorm2d-160           [-1, 2048, 7, 7]           4,096\n",
#     438       "            ReLU-161           [-1, 2048, 7, 7]               0\n",
#     439       "      BottleNeck-162           [-1, 2048, 7, 7]               0\n",
#     440       "          Conv2d-163            [-1, 512, 7, 7]       1,048,576\n",
#     441       "     BatchNorm2d-164            [-1, 512, 7, 7]           1,024\n",
#     442       "            ReLU-165            [-1, 512, 7, 7]               0\n",
#     443       "          Conv2d-166            [-1, 512, 7, 7]       2,359,296\n",
#     444       "     BatchNorm2d-167            [-1, 512, 7, 7]           1,024\n",
#     445       "            ReLU-168            [-1, 512, 7, 7]               0\n",
#     446       "          Conv2d-169           [-1, 2048, 7, 7]       1,048,576\n",
#     447       "     BatchNorm2d-170           [-1, 2048, 7, 7]           4,096\n",
#     448       "            ReLU-171           [-1, 2048, 7, 7]               0\n",
#     449       "      BottleNeck-172           [-1, 2048, 7, 7]               0\n",
#     450       "AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0\n",
#     451       "          Linear-174                   [-1, 10]          20,490\n",
#     452       "================================================================\n",
#     453       "Total params: 23,528,522\n",
#     454       "Trainable params: 23,528,522\n",
#     455       "Non-trainable params: 0\n",
#     456       "----------------------------------------------------------------\n",
#     457       "Input size (MB): 0.57\n",
#     458       "Forward/backward pass size (MB): 286.55\n",
#     459       "Params size (MB): 89.75\n",
#     460       "Estimated Total Size (MB): 376.88\n",
#     461       "----------------------------------------------------------------\n"
#     462      ]
#     463     }
#     464    ],
#     465    "source": [
#     466     "from torchsummary import summary\n",
#     467     "Res = ResNet(model=\"ResNet50\")\n",
#     468     "summary(Res.to(\"cpu\"), input_size=(3, 224, 224), device=\"cpu\")"
#     469    ]
#     470   },
#     471   {
#     472    "cell_type": "code",
#     473    "execution_count": 27,
#     474    "id": "41141c38-91f9-40c9-9720-bfe69607af29",
#     475    "metadata": {},
#     476    "outputs": [],
#     477    "source": [
#     478     "from torchvision import models\n",
#     479     "\n",
#     480     "ResNet50 = models.resnet50(weights=\"IMAGENET1K_V1\", progress=True)"
#     481    ]
#     482   },
#     483   {
#     484    "cell_type": "code",
#     485    "execution_count": 28,
#     486    "id": "226f6711-2826-41b5-b6c4-c2b45f97a498",
#     487    "metadata": {},
#     488    "outputs": [
#     489     {
#     490      "name": "stdout",
#     491      "output_type": "stream",
#     492      "text": [
#     493       "----------------------------------------------------------------\n",
#     494       "        Layer (type)               Output Shape         Param #\n",
#     495       "================================================================\n",
#     496       "            Conv2d-1         [-1, 64, 112, 112]           9,408\n",
#     497       "       BatchNorm2d-2         [-1, 64, 112, 112]             128\n",
#     498       "              ReLU-3         [-1, 64, 112, 112]               0\n",
#     499       "         MaxPool2d-4           [-1, 64, 56, 56]               0\n",
#     500       "            Conv2d-5           [-1, 64, 56, 56]           4,096\n",
#     501       "       BatchNorm2d-6           [-1, 64, 56, 56]             128\n",
#     502       "              ReLU-7           [-1, 64, 56, 56]               0\n",
#     503       "            Conv2d-8           [-1, 64, 56, 56]          36,864\n",
#     504       "       BatchNorm2d-9           [-1, 64, 56, 56]             128\n",
#     505       "             ReLU-10           [-1, 64, 56, 56]               0\n",
#     506       "           Conv2d-11          [-1, 256, 56, 56]          16,384\n",
#     507       "      BatchNorm2d-12          [-1, 256, 56, 56]             512\n",
#     508       "           Conv2d-13          [-1, 256, 56, 56]          16,384\n",
#     509       "      BatchNorm2d-14          [-1, 256, 56, 56]             512\n",
#     510       "             ReLU-15          [-1, 256, 56, 56]               0\n",
#     511       "       Bottleneck-16          [-1, 256, 56, 56]               0\n",
#     512       "           Conv2d-17           [-1, 64, 56, 56]          16,384\n",
#     513       "      BatchNorm2d-18           [-1, 64, 56, 56]             128\n",
#     514       "             ReLU-19           [-1, 64, 56, 56]               0\n",
#     515       "           Conv2d-20           [-1, 64, 56, 56]          36,864\n",
#     516       "      BatchNorm2d-21           [-1, 64, 56, 56]             128\n",
#     517       "             ReLU-22           [-1, 64, 56, 56]               0\n",
#     518       "           Conv2d-23          [-1, 256, 56, 56]          16,384\n",
#     519       "      BatchNorm2d-24          [-1, 256, 56, 56]             512\n",
#     520       "             ReLU-25          [-1, 256, 56, 56]               0\n",
#     521       "       Bottleneck-26          [-1, 256, 56, 56]               0\n",
#     522       "           Conv2d-27           [-1, 64, 56, 56]          16,384\n",
#     523       "      BatchNorm2d-28           [-1, 64, 56, 56]             128\n",
#     524       "             ReLU-29           [-1, 64, 56, 56]               0\n",
#     525       "           Conv2d-30           [-1, 64, 56, 56]          36,864\n",
#     526       "      BatchNorm2d-31           [-1, 64, 56, 56]             128\n",
#     527       "             ReLU-32           [-1, 64, 56, 56]               0\n",
#     528       "           Conv2d-33          [-1, 256, 56, 56]          16,384\n",
#     529       "      BatchNorm2d-34          [-1, 256, 56, 56]             512\n",
#     530       "             ReLU-35          [-1, 256, 56, 56]               0\n",
#     531       "       Bottleneck-36          [-1, 256, 56, 56]               0\n",
#     532       "           Conv2d-37          [-1, 128, 56, 56]          32,768\n",
#     533       "      BatchNorm2d-38          [-1, 128, 56, 56]             256\n",
#     534       "             ReLU-39          [-1, 128, 56, 56]               0\n",
#     535       "           Conv2d-40          [-1, 128, 28, 28]         147,456\n",
#     536       "      BatchNorm2d-41          [-1, 128, 28, 28]             256\n",
#     537       "             ReLU-42          [-1, 128, 28, 28]               0\n",
#     538       "           Conv2d-43          [-1, 512, 28, 28]          65,536\n",
#     539       "      BatchNorm2d-44          [-1, 512, 28, 28]           1,024\n",
#     540       "           Conv2d-45          [-1, 512, 28, 28]         131,072\n",
#     541       "      BatchNorm2d-46          [-1, 512, 28, 28]           1,024\n",
#     542       "             ReLU-47          [-1, 512, 28, 28]               0\n",
#     543       "       Bottleneck-48          [-1, 512, 28, 28]               0\n",
#     544       "           Conv2d-49          [-1, 128, 28, 28]          65,536\n",
#     545       "      BatchNorm2d-50          [-1, 128, 28, 28]             256\n",
#     546       "             ReLU-51          [-1, 128, 28, 28]               0\n",
#     547       "           Conv2d-52          [-1, 128, 28, 28]         147,456\n",
#     548       "      BatchNorm2d-53          [-1, 128, 28, 28]             256\n",
#     549       "             ReLU-54          [-1, 128, 28, 28]               0\n",
#     550       "           Conv2d-55          [-1, 512, 28, 28]          65,536\n",
#     551       "      BatchNorm2d-56          [-1, 512, 28, 28]           1,024\n",
#     552       "             ReLU-57          [-1, 512, 28, 28]               0\n",
#     553       "       Bottleneck-58          [-1, 512, 28, 28]               0\n",
#     554       "           Conv2d-59          [-1, 128, 28, 28]          65,536\n",
#     555       "      BatchNorm2d-60          [-1, 128, 28, 28]             256\n",
#     556       "             ReLU-61          [-1, 128, 28, 28]               0\n",
#     557       "           Conv2d-62          [-1, 128, 28, 28]         147,456\n",
#     558       "      BatchNorm2d-63          [-1, 128, 28, 28]             256\n",
#     559       "             ReLU-64          [-1, 128, 28, 28]               0\n",
#     560       "           Conv2d-65          [-1, 512, 28, 28]          65,536\n",
#     561       "      BatchNorm2d-66          [-1, 512, 28, 28]           1,024\n",
#     562       "             ReLU-67          [-1, 512, 28, 28]               0\n",
#     563       "       Bottleneck-68          [-1, 512, 28, 28]               0\n",
#     564       "           Conv2d-69          [-1, 128, 28, 28]          65,536\n",
#     565       "      BatchNorm2d-70          [-1, 128, 28, 28]             256\n",
#     566       "             ReLU-71          [-1, 128, 28, 28]               0\n",
#     567       "           Conv2d-72          [-1, 128, 28, 28]         147,456\n",
#     568       "      BatchNorm2d-73          [-1, 128, 28, 28]             256\n",
#     569       "             ReLU-74          [-1, 128, 28, 28]               0\n",
#     570       "           Conv2d-75          [-1, 512, 28, 28]          65,536\n",
#     571       "      BatchNorm2d-76          [-1, 512, 28, 28]           1,024\n",
#     572       "             ReLU-77          [-1, 512, 28, 28]               0\n",
#     573       "       Bottleneck-78          [-1, 512, 28, 28]               0\n",
#     574       "           Conv2d-79          [-1, 256, 28, 28]         131,072\n",
#     575       "      BatchNorm2d-80          [-1, 256, 28, 28]             512\n",
#     576       "             ReLU-81          [-1, 256, 28, 28]               0\n",
#     577       "           Conv2d-82          [-1, 256, 14, 14]         589,824\n",
#     578       "      BatchNorm2d-83          [-1, 256, 14, 14]             512\n",
#     579       "             ReLU-84          [-1, 256, 14, 14]               0\n",
#     580       "           Conv2d-85         [-1, 1024, 14, 14]         262,144\n",
#     581       "      BatchNorm2d-86         [-1, 1024, 14, 14]           2,048\n",
#     582       "           Conv2d-87         [-1, 1024, 14, 14]         524,288\n",
#     583       "      BatchNorm2d-88         [-1, 1024, 14, 14]           2,048\n",
#     584       "             ReLU-89         [-1, 1024, 14, 14]               0\n",
#     585       "       Bottleneck-90         [-1, 1024, 14, 14]               0\n",
#     586       "           Conv2d-91          [-1, 256, 14, 14]         262,144\n",
#     587       "      BatchNorm2d-92          [-1, 256, 14, 14]             512\n",
#     588       "             ReLU-93          [-1, 256, 14, 14]               0\n",
#     589       "           Conv2d-94          [-1, 256, 14, 14]         589,824\n",
#     590       "      BatchNorm2d-95          [-1, 256, 14, 14]             512\n",
#     591       "             ReLU-96          [-1, 256, 14, 14]               0\n",
#     592       "           Conv2d-97         [-1, 1024, 14, 14]         262,144\n",
#     593       "      BatchNorm2d-98         [-1, 1024, 14, 14]           2,048\n",
#     594       "             ReLU-99         [-1, 1024, 14, 14]               0\n",
#     595       "      Bottleneck-100         [-1, 1024, 14, 14]               0\n",
#     596       "          Conv2d-101          [-1, 256, 14, 14]         262,144\n",
#     597       "     BatchNorm2d-102          [-1, 256, 14, 14]             512\n",
#     598       "            ReLU-103          [-1, 256, 14, 14]               0\n",
#     599       "          Conv2d-104          [-1, 256, 14, 14]         589,824\n",
#     600       "     BatchNorm2d-105          [-1, 256, 14, 14]             512\n",
#     601       "            ReLU-106          [-1, 256, 14, 14]               0\n",
#     602       "          Conv2d-107         [-1, 1024, 14, 14]         262,144\n",
#     603       "     BatchNorm2d-108         [-1, 1024, 14, 14]           2,048\n",
#     604       "            ReLU-109         [-1, 1024, 14, 14]               0\n",
#     605       "      Bottleneck-110         [-1, 1024, 14, 14]               0\n",
#     606       "          Conv2d-111          [-1, 256, 14, 14]         262,144\n",
#     607       "     BatchNorm2d-112          [-1, 256, 14, 14]             512\n",
#     608       "            ReLU-113          [-1, 256, 14, 14]               0\n",
#     609       "          Conv2d-114          [-1, 256, 14, 14]         589,824\n",
#     610       "     BatchNorm2d-115          [-1, 256, 14, 14]             512\n",
#     611       "            ReLU-116          [-1, 256, 14, 14]               0\n",
#     612       "          Conv2d-117         [-1, 1024, 14, 14]         262,144\n",
#     613       "     BatchNorm2d-118         [-1, 1024, 14, 14]           2,048\n",
#     614       "            ReLU-119         [-1, 1024, 14, 14]               0\n",
#     615       "      Bottleneck-120         [-1, 1024, 14, 14]               0\n",
#     616       "          Conv2d-121          [-1, 256, 14, 14]         262,144\n",
#     617       "     BatchNorm2d-122          [-1, 256, 14, 14]             512\n",
#     618       "            ReLU-123          [-1, 256, 14, 14]               0\n",
#     619       "          Conv2d-124          [-1, 256, 14, 14]         589,824\n",
#     620       "     BatchNorm2d-125          [-1, 256, 14, 14]             512\n",
#     621       "            ReLU-126          [-1, 256, 14, 14]               0\n",
#     622       "          Conv2d-127         [-1, 1024, 14, 14]         262,144\n",
#     623       "     BatchNorm2d-128         [-1, 1024, 14, 14]           2,048\n",
#     624       "            ReLU-129         [-1, 1024, 14, 14]               0\n",
#     625       "      Bottleneck-130         [-1, 1024, 14, 14]               0\n",
#     626       "          Conv2d-131          [-1, 256, 14, 14]         262,144\n",
#     627       "     BatchNorm2d-132          [-1, 256, 14, 14]             512\n",
#     628       "            ReLU-133          [-1, 256, 14, 14]               0\n",
#     629       "          Conv2d-134          [-1, 256, 14, 14]         589,824\n",
#     630       "     BatchNorm2d-135          [-1, 256, 14, 14]             512\n",
#     631       "            ReLU-136          [-1, 256, 14, 14]               0\n",
#     632       "          Conv2d-137         [-1, 1024, 14, 14]         262,144\n",
#     633       "     BatchNorm2d-138         [-1, 1024, 14, 14]           2,048\n",
#     634       "            ReLU-139         [-1, 1024, 14, 14]               0\n",
#     635       "      Bottleneck-140         [-1, 1024, 14, 14]               0\n",
#     636       "          Conv2d-141          [-1, 512, 14, 14]         524,288\n",
#     637       "     BatchNorm2d-142          [-1, 512, 14, 14]           1,024\n",
#     638       "            ReLU-143          [-1, 512, 14, 14]               0\n",
#     639       "          Conv2d-144            [-1, 512, 7, 7]       2,359,296\n",
#     640       "     BatchNorm2d-145            [-1, 512, 7, 7]           1,024\n",
#     641       "            ReLU-146            [-1, 512, 7, 7]               0\n",
#     642       "          Conv2d-147           [-1, 2048, 7, 7]       1,048,576\n",
#     643       "     BatchNorm2d-148           [-1, 2048, 7, 7]           4,096\n",
#     644       "          Conv2d-149           [-1, 2048, 7, 7]       2,097,152\n",
#     645       "     BatchNorm2d-150           [-1, 2048, 7, 7]           4,096\n",
#     646       "            ReLU-151           [-1, 2048, 7, 7]               0\n",
#     647       "      Bottleneck-152           [-1, 2048, 7, 7]               0\n",
#     648       "          Conv2d-153            [-1, 512, 7, 7]       1,048,576\n",
#     649       "     BatchNorm2d-154            [-1, 512, 7, 7]           1,024\n",
#     650       "            ReLU-155            [-1, 512, 7, 7]               0\n",
#     651       "          Conv2d-156            [-1, 512, 7, 7]       2,359,296\n",
#     652       "     BatchNorm2d-157            [-1, 512, 7, 7]           1,024\n",
#     653       "            ReLU-158            [-1, 512, 7, 7]               0\n",
#     654       "          Conv2d-159           [-1, 2048, 7, 7]       1,048,576\n",
#     655       "     BatchNorm2d-160           [-1, 2048, 7, 7]           4,096\n",
#     656       "            ReLU-161           [-1, 2048, 7, 7]               0\n",
#     657       "      Bottleneck-162           [-1, 2048, 7, 7]               0\n",
#     658       "          Conv2d-163            [-1, 512, 7, 7]       1,048,576\n",
#     659       "     BatchNorm2d-164            [-1, 512, 7, 7]           1,024\n",
#     660       "            ReLU-165            [-1, 512, 7, 7]               0\n",
#     661       "          Conv2d-166            [-1, 512, 7, 7]       2,359,296\n",
#     662       "     BatchNorm2d-167            [-1, 512, 7, 7]           1,024\n",
#     663       "            ReLU-168            [-1, 512, 7, 7]               0\n",
#     664       "          Conv2d-169           [-1, 2048, 7, 7]       1,048,576\n",
#     665       "     BatchNorm2d-170           [-1, 2048, 7, 7]           4,096\n",
#     666       "            ReLU-171           [-1, 2048, 7, 7]               0\n",
#     667       "      Bottleneck-172           [-1, 2048, 7, 7]               0\n",
#     668       "AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0\n",
#     669       "          Linear-174                 [-1, 1000]       2,049,000\n",
#     670       "================================================================\n",
#     671       "Total params: 25,557,032\n",
#     672       "Trainable params: 25,557,032\n",
#     673       "Non-trainable params: 0\n",
#     674       "----------------------------------------------------------------\n",
#     675       "Input size (MB): 0.57\n",
#     676       "Forward/backward pass size (MB): 286.56\n",
#     677       "Params size (MB): 97.49\n",
#     678       "Estimated Total Size (MB): 384.62\n",
#     679       "----------------------------------------------------------------\n"
#     680      ]
#     681     }
#     682    ],
#     683    "source": [
#     684     "summary(ResNet50.to(\"cpu\"), input_size=(3, 224, 224), device=\"cpu\")"
#     685    ]
#     686   },
#     687   {
#     688    "cell_type": "markdown",
#     689    "id": "d6723c3a-7e9f-42a6-b0c1-3f53cd8d0245",
#     690    "metadata": {},
#     691    "source": [
#     692     "# Train / Evaluate"
#     693    ]
#     694   },
#     695   {
#     696    "cell_type": "code",
#     697    "execution_count": 57,
#     698    "id": "f0cdb235-7023-49ad-bfb4-d4f46d6ae17c",
#     699    "metadata": {},
#     700    "outputs": [],
#     701    "source": [
#     702     "def train(model: torch.nn.Module,\n",
#     703     "          dataloader: torch.utils.data.DataLoader,\n",
#     704     "          optimizer: torch.optim.Optimizer,\n",
#     705     "          loss_fn: torch.nn.Module):\n",
#     706     "    \n",
#     707     "    model.train()\n",
#     708     "    train_loss, train_acc, correct = 0, 0, 0\n",
#     709     "        \n",
#     710     "    for X, y in dataloader:\n",
#     711     "        X, y = X.to(DEVICE), y.to(DEVICE)\n",
#     712     "        # Forward pass\n",
#     713     "        preds_prob = model(X) # Shape of preds_prob = (batch_size, num_classes)\n",
#     714     "        # Calculate the loss\n",
#     715     "        loss = loss_fn(preds_prob, y) # Shape of loss = [float] (i.e. scalar tensor containing the average loss over the batch)\n",
#     716     "        train_loss += loss.item()\n",
#     717     "        # Optimizer zero_grad\n",
#     718     "        optimizer.zero_grad()\n",
#     719     "        # Loss backward\n",
#     720     "        loss.backward()\n",
#     721     "        # Update\n",
#     722     "        optimizer.step()\n",
#     723     "\n",
#     724     "        preds = torch.argmax(preds_prob, dim=1) # max values over the num_classes of (batch_size, num_classes)\n",
#     725     "        correct += preds.eq(y.view_as(preds)).sum().item()\n",
#     726     "\n",
#     727     "    train_loss /= len(dataloader)\n",
#     728     "    train_acc = 100. * correct / len(dataloader.dataset)\n",
#     729     "\n",
#     730     "    return train_loss, train_acc"
#     731    ]
#     732   },
#     733   {
#     734    "cell_type": "code",
#     735    "execution_count": 65,
#     736    "id": "0bd63882-2c8c-401f-ae3d-bb6366d71998",
#     737    "metadata": {},
#     738    "outputs": [],
#     739    "source": [
#     740     "def evaluate(model: torch.nn.Module,\n",
#     741     "             dataloader: torch.utils.data.DataLoader,\n",
#     742     "             loss_fn: torch.nn.Module):\n",
#     743     "    model.eval()\n",
#     744     "    val_loss, val_acc, correct = 0, 0, 0\n",
#     745     "\n",
#     746     "    with torch.no_grad():\n",
#     747     "        for X, y in dataloader:\n",
#     748     "            X, y = X.to(DEVICE), y.to(DEVICE)\n",
#     749     "            # Forward pass\n",
#     750     "            preds_prob = model(X)\n",
#     751     "            # Calculate the loss\n",
#     752     "            loss = loss_fn(preds_prob, y)\n",
#     753     "            val_loss += loss.item()\n",
#     754     "\n",
#     755     "            preds = torch.argmax(preds_prob, dim=1)\n",
#     756     "            correct += preds.eq(y.view_as(preds)).sum().item()\n",
#     757     "\n",
#     758     "        val_loss /= len(dataloader)\n",
#     759     "        val_acc = 100. * correct / len(dataloader.dataset)\n",
# ...
#     582       "           Conv2d-87         [-1, 1024, 14, 14]         524,288\n",
#     583       "      BatchNorm2d-88         [-1, 1024, 14, 14]           2,048\n",
#     584       "             ReLU-89         [-1, 1024, 14, 14]               0\n",
#     585       "       Bottleneck-90         [-1, 1024, 14, 14]               0\n",
#     586       "           Conv2d-91          [-1, 256, 14, 14]         262,144\n",
#     587       "      BatchNorm2d-92          [-1, 256, 14, 14]             512\n",
#     588       "             ReLU-93          [-1, 256, 14, 14]               0\n",
#     589       "           Conv2d-94          [-1, 256, 14, 14]         589,824\n",
#     590       "      BatchNorm2d-95          [-1, 256, 14, 14]             512\n",
#     591       "             ReLU-96          [-1, 256, 14, 14]               0\n",
#     592       "           Conv2d-97         [-1, 1024, 14, 14]         262,144\n",
#     593       "      BatchNorm2d-98         [-1, 1024, 14, 14]           2,048\n",
#     594       "             ReLU-99         [-1, 1024, 14, 14]               0\n",
#     595       "      Bottleneck-100         [-1, 1024, 14, 14]               0\n",
#     596       "          Conv2d-101          [-1, 256, 14, 14]         262,144\n",
#     597       "     BatchNorm2d-102          [-1, 256, 14, 14]             512\n",
#     598       "            ReLU-103          [-1, 256, 14, 14]               0\n",
#     599       "          Conv2d-104          [-1, 256, 14, 14]         589,824\n",
#     600       "     BatchNorm2d-105          [-1, 256, 14, 14]             512\n",
#     601       "            ReLU-106          [-1, 256, 14, 14]               0\n",
#     602       "          Conv2d-107         [-1, 1024, 14, 14]         262,144\n",
#     603       "     BatchNorm2d-108         [-1, 1024, 14, 14]           2,048\n",
#     604       "            ReLU-109         [-1, 1024, 14, 14]               0\n",
#     605       "      Bottleneck-110         [-1, 1024, 14, 14]               0\n",
#     606       "          Conv2d-111          [-1, 256, 14, 14]         262,144\n",
#     607       "     BatchNorm2d-112          [-1, 256, 14, 14]             512\n",
#     608       "            ReLU-113          [-1, 256, 14, 14]               0\n",
#     609       "          Conv2d-114          [-1, 256, 14, 14]         589,824\n",
#     610       "     BatchNorm2d-115          [-1, 256, 14, 14]             512\n",
#     611       "            ReLU-116          [-1, 256, 14, 14]               0\n",
#     612       "          Conv2d-117         [-1, 1024, 14, 14]         262,144\n",
#     613       "     BatchNorm2d-118         [-1, 1024, 14, 14]           2,048\n",
#     614       "            ReLU-119         [-1, 1024, 14, 14]               0\n",
#     615       "      Bottleneck-120         [-1, 1024, 14, 14]               0\n",
#     616       "          Conv2d-121          [-1, 256, 14, 14]         262,144\n",
#     617       "     BatchNorm2d-122          [-1, 256, 14, 14]             512\n",
#     618       "            ReLU-123          [-1, 256, 14, 14]               0\n",
#     619       "          Conv2d-124          [-1, 256, 14, 14]         589,824\n",
#     620       "     BatchNorm2d-125          [-1, 256, 14, 14]             512\n",
#     621       "            ReLU-126          [-1, 256, 14, 14]               0\n",
#     622       "          Conv2d-127         [-1, 1024, 14, 14]         262,144\n",
#     623       "     BatchNorm2d-128         [-1, 1024, 14, 14]           2,048\n",
#     624       "            ReLU-129         [-1, 1024, 14, 14]               0\n",
#     625       "      Bottleneck-130         [-1, 1024, 14, 14]               0\n",
#     626       "          Conv2d-131          [-1, 256, 14, 14]         262,144\n",
#     627       "     BatchNorm2d-132          [-1, 256, 14, 14]             512\n",
#     628       "            ReLU-133          [-1, 256, 14, 14]               0\n",
#     629       "          Conv2d-134          [-1, 256, 14, 14]         589,824\n",
#     630       "     BatchNorm2d-135          [-1, 256, 14, 14]             512\n",
#     631       "            ReLU-136          [-1, 256, 14, 14]               0\n",
#     632       "          Conv2d-137         [-1, 1024, 14, 14]         262,144\n",
#     633       "     BatchNorm2d-138         [-1, 1024, 14, 14]           2,048\n",
#     634       "            ReLU-139         [-1, 1024, 14, 14]               0\n",
#     635       "      Bottleneck-140         [-1, 1024, 14, 14]               0\n",
#     636       "          Conv2d-141          [-1, 512, 14, 14]         524,288\n",
#     637       "     BatchNorm2d-142          [-1, 512, 14, 14]           1,024\n",
#     638       "            ReLU-143          [-1, 512, 14, 14]               0\n",
#     639       "          Conv2d-144            [-1, 512, 7, 7]       2,359,296\n",
#     640       "     BatchNorm2d-145            [-1, 512, 7, 7]           1,024\n",
#     641       "            ReLU-146            [-1, 512, 7, 7]               0\n",
#     642       "          Conv2d-147           [-1, 2048, 7, 7]       1,048,576\n",
#     643       "     BatchNorm2d-148           [-1, 2048, 7, 7]           4,096\n",
#     644       "          Conv2d-149           [-1, 2048, 7, 7]       2,097,152\n",
#     645       "     BatchNorm2d-150           [-1, 2048, 7, 7]           4,096\n",
#     646       "            ReLU-151           [-1, 2048, 7, 7]               0\n",
#     647       "      Bottleneck-152           [-1, 2048, 7, 7]               0\n",
#     648       "          Conv2d-153            [-1, 512, 7, 7]       1,048,576\n",
#     649       "     BatchNorm2d-154            [-1, 512, 7, 7]           1,024\n",
#     650       "            ReLU-155            [-1, 512, 7, 7]               0\n",
#     651       "          Conv2d-156            [-1, 512, 7, 7]       2,359,296\n",
#     652       "     BatchNorm2d-157            [-1, 512, 7, 7]           1,024\n",
#     653       "            ReLU-158            [-1, 512, 7, 7]               0\n",
#     654       "          Conv2d-159           [-1, 2048, 7, 7]       1,048,576\n",
#     655       "     BatchNorm2d-160           [-1, 2048, 7, 7]           4,096\n",
#     656       "            ReLU-161           [-1, 2048, 7, 7]               0\n",
#     657       "      Bottleneck-162           [-1, 2048, 7, 7]               0\n",
#     658       "          Conv2d-163            [-1, 512, 7, 7]       1,048,576\n",
#     659       "     BatchNorm2d-164            [-1, 512, 7, 7]           1,024\n",
#     660       "            ReLU-165            [-1, 512, 7, 7]               0\n",
#     661       "          Conv2d-166            [-1, 512, 7, 7]       2,359,296\n",
#     662       "     BatchNorm2d-167            [-1, 512, 7, 7]           1,024\n",
#     663       "            ReLU-168            [-1, 512, 7, 7]               0\n",
#     664       "          Conv2d-169           [-1, 2048, 7, 7]       1,048,576\n",
#     665       "     BatchNorm2d-170           [-1, 2048, 7, 7]           4,096\n",
#     666       "            ReLU-171           [-1, 2048, 7, 7]               0\n",
#     667       "      Bottleneck-172           [-1, 2048, 7, 7]               0\n",
#     668       "AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0\n",
#     669       "          Linear-174                 [-1, 1000]       2,049,000\n",
#     670       "================================================================\n",
#     671       "Total params: 25,557,032\n",
#     672       "Trainable params: 25,557,032\n",
#     673       "Non-trainable params: 0\n",
#     674       "----------------------------------------------------------------\n",
#     675       "Input size (MB): 0.57\n",
#     676       "Forward/backward pass size (MB): 286.56\n",
#     677       "Params size (MB): 97.49\n",
#     678       "Estimated Total Size (MB): 384.62\n",
#     679       "----------------------------------------------------------------\n"
#     680      ]
#     681     }
#     682    ],
#     683    "source": [
#     684     "summary(ResNet50.to(\"cpu\"), input_size=(3, 224, 224), device=\"cpu\")"
#     685    ]
#     686   },
#     687   {
#     688    "cell_type": "markdown",
#     689    "id": "d6723c3a-7e9f-42a6-b0c1-3f53cd8d0245",
#     690    "metadata": {},
#     691    "source": [
#     692     "# Train / Evaluate"
#     693    ]
#     694   },
#     695   {
#     696    "cell_type": "code",
#     697    "execution_count": 57,
#     698    "id": "f0cdb235-7023-49ad-bfb4-d4f46d6ae17c",
#     699    "metadata": {},
#     700    "outputs": [],
#     701    "source": [
#     702     "def train(model: torch.nn.Module,\n",
#     703     "          dataloader: torch.utils.data.DataLoader,\n",
#     704     "          optimizer: torch.optim.Optimizer,\n",
#     705     "          loss_fn: torch.nn.Module):\n",
#     706     "    \n",
#     707     "    model.train()\n",
#     708     "    train_loss, train_acc, correct = 0, 0, 0\n",
#     709     "        \n",
#     710     "    for X, y in dataloader:\n",
#     711     "        X, y = X.to(DEVICE), y.to(DEVICE)\n",
#     712     "        # Forward pass\n",
#     713     "        preds_prob = model(X) # Shape of preds_prob = (batch_size, num_classes)\n",
#     714     "        # Calculate the loss\n",
#     715     "        loss = loss_fn(preds_prob, y) # Shape of loss = [float] (i.e. scalar tensor containing the average loss over the batch)\n",
#     716     "        train_loss += loss.item()\n",
#     717     "        # Optimizer zero_grad\n",
#     718     "        optimizer.zero_grad()\n",
#     719     "        # Loss backward\n",
#     720     "        loss.backward()\n",
#     721     "        # Update\n",
#     722     "        optimizer.step()\n",
#     723     "\n",
#     724     "        preds = torch.argmax(preds_prob, dim=1) # max values over the num_classes of (batch_size, num_classes)\n",
#     725     "        correct += preds.eq(y.view_as(preds)).sum().item()\n",
#     726     "\n",
#     727     "    train_loss /= len(dataloader)\n",
#     728     "    train_acc = 100. * correct / len(dataloader.dataset)\n",
#     729     "\n",
#     730     "    return train_loss, train_acc"
#     731    ]
#     732   },
#     733   {
#     734    "cell_type": "code",
#     735    "execution_count": 65,
#     736    "id": "0bd63882-2c8c-401f-ae3d-bb6366d71998",
#     737    "metadata": {},
#     738    "outputs": [],
#     739    "source": [
#     740     "def evaluate(model: torch.nn.Module,\n",
#     741     "             dataloader: torch.utils.data.DataLoader,\n",
#     742     "             loss_fn: torch.nn.Module):\n",
#     743     "    model.eval()\n",
#     744     "    val_loss, val_acc, correct = 0, 0, 0\n",
#     745     "\n",
#     746     "    with torch.no_grad():\n",
#     747     "        for X, y in dataloader:\n",
#     748     "            X, y = X.to(DEVICE), y.to(DEVICE)\n",
#     749     "            # Forward pass\n",
#     750     "            preds_prob = model(X)\n",
#     751     "            # Calculate the loss\n",
#     752     "            loss = loss_fn(preds_prob, y)\n",
#     753     "            val_loss += loss.item()\n",
#     754     "\n",
#     755     "            preds = torch.argmax(preds_prob, dim=1)\n",
#     756     "            correct += preds.eq(y.view_as(preds)).sum().item()\n",
#     757     "\n",
#     758     "        val_loss /= len(dataloader)\n",
#     759     "        val_acc = 100. * correct / len(dataloader.dataset)\n",
#     760     "\n",
#     761     "    return val_loss, val_acc"
#     762    ]
#     763   },
#     764   {
#     765    "cell_type": "code",
#     766    "execution_count": 59,
#     767    "id": "4f735ded-7641-4b81-906a-80d03be6b1cf",
#     768    "metadata": {},
#     769    "outputs": [],
#     770    "source": [
#     771     "def train_baseline(model: torch.nn.Module,\n",
#     772     "                   train_dataloader: torch.utils.data.DataLoader,\n",
#     773     "                   val_dataloader: torch.utils.data.DataLoader,\n",
#     774     "                   optimizer: torch.optim.Optimizer,\n",
#     775     "                   loss_fn: torch.nn.Module,\n",
#     776     "                   num_epochs: int):\n",
#     777     "\n",
#     778     "    best_acc = 0\n",
#     779     "    best_model_wts = copy.deepcopy(model.state_dict())\n",
#     780     "    for epoch in range(1, num_epochs + 1):\n",
#     781     "        strat = time.time()\n",
#     782     "        train_loss, train_acc = train(model, train_dataloader, optimizer, loss_fn)\n",
#     783     "        test_loss, test_acc = evaluate(model, val_dataloader, loss_fn)\n",
#     784     "\n",
#     785     "        if test_acc > best_acc:\n",
#     786     "            best_acc = test_acc\n",
#     787     "            best_model_wts = copy.deepcopy(model.state_dict())\n",
#     788     "\n",
#     789     "        end = time.time()\n",
#     790     "        time_elapsed = end_time - start_time\n",
#     791     "        print(f\"------------ epoch {epoch} ------------\")\n",
#     792     "        print(f\"Train loss: {train_loss:.4f} | Train acc: {train_acc:.2f}%\")\n",
#     793     "        print(f\"Val loss: {val_loss:.4f} | Val acc: {val_acc:2f}%\")\n",
#     794     "        print(f\"Time taken: {time_elapsed / 60:.0f}min {time_elapsed % 60:.0f}s\")\n",
#     795     "\n",
#     796     "    model.load_state_dict(best_model_wts)\n",
#     797     "    return model"
#     798    ]
#     799   },
#     800   {
#     801    "cell_type": "markdown",
#     802    "id": "c9b2fa20-d073-4104-9871-747e63b68cb4",
#     803    "metadata": {},
#     804    "source": [
#     805     "# Train baseline model"
#     806    ]
#     807   },
#     808   {
#     809    "cell_type": "code",
#     810    "execution_count": 60,
#     811    "id": "38a672a2-286d-485b-83cd-af9724263c7b",
#     812    "metadata": {},
#     813    "outputs": [
#     814     {
#     815      "name": "stdout",
#     816      "output_type": "stream",
#     817      "text": [
#     818       "Device : mps\n"
#     819      ]
#     820     }
#     821    ],
#     822    "source": [
#     823     "DEVICE = \"mps\" if torch.backends.mps.is_available() else \"cpu\"\n",
#     824     "print(f\"Device : {DEVICE}\")"
#     825    ]
#     826   },
#     827   {
#     828    "cell_type": "code",
#     829    "execution_count": 66,
#     830    "id": "7597bbba-a95b-40cc-b3b0-6dc9261561c3",
#     831    "metadata": {},
#     832    "outputs": [],
#     833    "source": [
#     834     "ResNet50 = ResNet(in_channels=3, model=\"ResNet50\", num_classes=10).to(DEVICE)\n",
#     835     "loss_fn = nn.CrossEntropyLoss()\n",
#     836     "optimizer = torch.optim.Adam(ResNet50.parameters(), lr = 0.001)\n",
#     837     "scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.3)"
#     838    ]
#     839   },
#     840   {
#     841    "cell_type": "code",
#     842    "execution_count": null,
#     843    "id": "bd169dd8-de23-4cec-b467-fe303c3c32d7",
#     844    "metadata": {},
#     845    "outputs": [],
#     846    "source": [
#     847     "base = train_baseline(ResNet50,\n",
#     848     "                      train_dataloader,\n",
#     849     "                      val_dataloader,\n",
#     850     "                      optimizer,\n",
#     851     "                      loss_fn,\n",
#     852     "                      num_epochs=5)"
#     853    ]
#     854   },
#     855   {
#     856    "cell_type": "code",
#     857    "execution_count": null,
#     858    "id": "7ad29b6e-e890-431d-aa1a-a8204c50c4bc",
#     859    "metadata": {},
#     860    "outputs": [],
#     861    "source": []
#     862   }
#     863  ],
#     864  "metadata": {
#     865   "kernelspec": {
#     866    "display_name": "Python (env)",
#     867    "language": "python",
#     868    "name": "env"
#     869   },
#     870   "language_info": {
#     871    "codemirror_mode": {
#     872     "name": "ipython",
#     873     "version": 3
#     874    },
#     875    "file_extension": ".py",
#     876    "mimetype": "text/x-python",
#     877    "name": "python",
#     878    "nbconvert_exporter": "python",
#     879    "pygments_lexer": "ipython3",
#     880    "version": "3.8.19"
#     881   }
#     882  },
#     883  "nbformat": 4,
#     884  "nbformat_minor": 5
#     885 }
#
# NameError: name 'DEVICE' is not defined
